# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
# !unzip processed_celeba_small.zip
# Out:
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    transform = transforms.Compose([
        transforms.Resize((image_size, image_size)),
        transforms.ToTensor()
    ])
    dataset = datasets.ImageFolder(data_dir, transform=transform)
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)
    return dataloader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 64
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    bias = feature_range[0]
    slope = feature_range[1] - feature_range[0]
    x = slope*x + bias
    
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9451)
# Max:  tensor(1.)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
def conv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    
    layers = []
    
    conv_layer = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding, bias=False)
    
    layers.append(conv_layer)
    
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
    
    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim
        
        self.conv1 = conv(3, conv_dim, 4, batch_norm=False)
        self.conv2 = conv(conv_dim, conv_dim*2, 4)
        self.conv3 = conv(conv_dim*2, conv_dim*4, 4)
        
        self.fc = nn.Linear(conv_dim*4*4*4, 1)

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        out = F.leaky_relu(self.conv1(x), 0.2)
        out = F.leaky_relu(self.conv2(out), 0.2)
        out = F.leaky_relu(self.conv3(out), 0.2)
        
        out = out.view(-1, self.conv_dim*4*4*4)
        out = self.fc(out)
        return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
def trans_conv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    
    layers = []
    
    trans_conv_layer = nn.ConvTranspose2d(in_channels, out_channels, kernel_size, stride, padding, bias=False)
    
    layers.append(trans_conv_layer)
    
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
    
    return nn.Sequential(*layers)

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim
        
        self.fc = nn.Linear(z_size, conv_dim*4*4*4)
        
        self.t_conv1 = trans_conv(conv_dim*4, conv_dim*2, 4)
        self.t_conv2 = trans_conv(conv_dim*2, conv_dim, 4)
        self.t_conv3 = trans_conv(conv_dim, 3, 4, batch_norm=False)
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        out = self.fc(x)
        out = out.view(-1, self.conv_dim*4, 4, 4)
        out = F.relu(self.t_conv1(out))
        out = F.relu(self.t_conv2(out))
        out = self.t_conv3(out)
        out = F.tanh(out)
        
        return out

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed
# C:\Users\halsa\miniconda3\envs\get_started_pytorch\lib\site-packages\torch\nn\functional.py:1558: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    # TODO: Apply initial weights to convolutional and linear layers
    if classname.find('Linear') != -1:
        m.weight.data.normal_(0, 0.02)
        if m.bias is not None:
            m.bias.data.fill_(0)
        
    if classname.find('Conv') != -1:
        m.weight.data.normal_(0, 0.02)
        if m.bias is not None:
            m.bias.fill_(0)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 32
g_conv_dim = 32
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=2048, bias=True)
#   (t_conv1): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv2): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv3): Sequential(
#     (0): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_size = D_out.size(0)
    labels = torch.ones(batch_size)
    
    if train_on_gpu:
        labels = labels.cuda()
        
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size)
    
    if train_on_gpu:
        labels = labels.cuda()
        
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

# Create optimizers for the discriminator D and generator G
lr = 0.0002
beta1 = 0.5
beta2 = 0.999

d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # 1. Train the discriminator on real and fake images
            d_optimizer.zero_grad()
            
            if train_on_gpu:
                real_images = real_images.cuda()
            
            D_real = D(real_images)
            d_real_loss = real_loss(D_real)
            
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            
            if train_on_gpu:
                z = z.cuda()
            
            fake_images = G(z)
                
            D_fake = D(fake_images)
            d_fake_loss = fake_loss(D_fake)
            
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step()

            # 2. Train the generator with an adversarial loss
            g_optimizer.zero_grad()
            
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda()
                
            fake_images = G(z)
            
            D_fake = D(fake_images)
            g_loss = real_loss(D_fake)
            
            g_loss.backward()
            g_optimizer.step()

            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 50


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   50] | d_loss: 0.4008 | g_loss: 2.3461
# Epoch [    1/   50] | d_loss: 0.1389 | g_loss: 3.6200
# Epoch [    1/   50] | d_loss: 0.2309 | g_loss: 2.7223
# Epoch [    1/   50] | d_loss: 0.5453 | g_loss: 1.1432
# Epoch [    1/   50] | d_loss: 0.4413 | g_loss: 3.1507
# Epoch [    1/   50] | d_loss: 0.3849 | g_loss: 2.4924
# Epoch [    1/   50] | d_loss: 0.6696 | g_loss: 1.9218
# Epoch [    1/   50] | d_loss: 0.7841 | g_loss: 1.7427
# Epoch [    2/   50] | d_loss: 0.7054 | g_loss: 3.3713
# Epoch [    2/   50] | d_loss: 0.5863 | g_loss: 1.6660
# Epoch [    2/   50] | d_loss: 0.8873 | g_loss: 2.0313
# Epoch [    2/   50] | d_loss: 0.6063 | g_loss: 1.5280
# Epoch [    2/   50] | d_loss: 0.8409 | g_loss: 1.8260
# Epoch [    2/   50] | d_loss: 0.7903 | g_loss: 2.5860
# Epoch [    2/   50] | d_loss: 0.8683 | g_loss: 3.0022
# Epoch [    2/   50] | d_loss: 1.2325 | g_loss: 0.6422
# Epoch [    3/   50] | d_loss: 0.9775 | g_loss: 1.4268
# Epoch [    3/   50] | d_loss: 0.8024 | g_loss: 2.0533
# Epoch [    3/   50] | d_loss: 0.9756 | g_loss: 1.5851
# Epoch [    3/   50] | d_loss: 0.8171 | g_loss: 1.3726
# Epoch [    3/   50] | d_loss: 1.1257 | g_loss: 1.3191
# Epoch [    3/   50] | d_loss: 0.7871 | g_loss: 1.3651
# Epoch [    3/   50] | d_loss: 1.0130 | g_loss: 1.0374
# Epoch [    3/   50] | d_loss: 0.9358 | g_loss: 1.4402
# Epoch [    4/   50] | d_loss: 1.0455 | g_loss: 0.9377
# Epoch [    4/   50] | d_loss: 1.0164 | g_loss: 1.1184
# Epoch [    4/   50] | d_loss: 1.0493 | g_loss: 0.7158
# Epoch [    4/   50] | d_loss: 0.9173 | g_loss: 1.5640
# Epoch [    4/   50] | d_loss: 0.8555 | g_loss: 1.3962
# Epoch [    4/   50] | d_loss: 0.9058 | g_loss: 1.2685
# Epoch [    4/   50] | d_loss: 0.8281 | g_loss: 2.2996
# Epoch [    4/   50] | d_loss: 1.3781 | g_loss: 1.6173
# Epoch [    5/   50] | d_loss: 1.6146 | g_loss: 1.7585
# Epoch [    5/   50] | d_loss: 1.0357 | g_loss: 1.3091
# Epoch [    5/   50] | d_loss: 0.9902 | g_loss: 1.4557
# Epoch [    5/   50] | d_loss: 0.9456 | g_loss: 1.0299
# Epoch [    5/   50] | d_loss: 1.0392 | g_loss: 0.6012
# Epoch [    5/   50] | d_loss: 1.0304 | g_loss: 1.3778
# Epoch [    5/   50] | d_loss: 1.1458 | g_loss: 1.3969
# Epoch [    5/   50] | d_loss: 0.9464 | g_loss: 1.2292
# Epoch [    6/   50] | d_loss: 1.5524 | g_loss: 1.9018
# Epoch [    6/   50] | d_loss: 0.9469 | g_loss: 1.6821
# Epoch [    6/   50] | d_loss: 0.9965 | g_loss: 1.7741
# Epoch [    6/   50] | d_loss: 1.1886 | g_loss: 1.0628
# Epoch [    6/   50] | d_loss: 1.0963 | g_loss: 0.8597
# Epoch [    6/   50] | d_loss: 0.9900 | g_loss: 1.2877
# Epoch [    6/   50] | d_loss: 1.0015 | g_loss: 1.4079
# Epoch [    6/   50] | d_loss: 1.0079 | g_loss: 1.2530
# Epoch [    7/   50] | d_loss: 0.8472 | g_loss: 0.9045
# Epoch [    7/   50] | d_loss: 1.1181 | g_loss: 1.4985
# Epoch [    7/   50] | d_loss: 1.1242 | g_loss: 0.9190
# Epoch [    7/   50] | d_loss: 1.1149 | g_loss: 1.2217
# Epoch [    7/   50] | d_loss: 0.8927 | g_loss: 0.7486
# Epoch [    7/   50] | d_loss: 1.1486 | g_loss: 1.1550
# Epoch [    7/   50] | d_loss: 0.6451 | g_loss: 1.4315
# Epoch [    7/   50] | d_loss: 1.0680 | g_loss: 1.2476
# Epoch [    8/   50] | d_loss: 1.0763 | g_loss: 1.2951
# Epoch [    8/   50] | d_loss: 0.7280 | g_loss: 2.2830
# Epoch [    8/   50] | d_loss: 0.8920 | g_loss: 1.2178
# Epoch [    8/   50] | d_loss: 1.0863 | g_loss: 1.5249
# Epoch [    8/   50] | d_loss: 0.6925 | g_loss: 1.1617
# Epoch [    8/   50] | d_loss: 1.3681 | g_loss: 1.6028
# Epoch [    8/   50] | d_loss: 1.0607 | g_loss: 0.9940
# Epoch [    8/   50] | d_loss: 1.3630 | g_loss: 1.1554
# Epoch [    9/   50] | d_loss: 0.9069 | g_loss: 1.5109
# Epoch [    9/   50] | d_loss: 1.1722 | g_loss: 1.0883
# Epoch [    9/   50] | d_loss: 1.2278 | g_loss: 0.6468
# Epoch [    9/   50] | d_loss: 0.7220 | g_loss: 1.7514
# Epoch [    9/   50] | d_loss: 1.0571 | g_loss: 1.5438
# Epoch [    9/   50] | d_loss: 0.9149 | g_loss: 1.1955
# Epoch [    9/   50] | d_loss: 1.2384 | g_loss: 1.7806
# Epoch [    9/   50] | d_loss: 0.5930 | g_loss: 1.7218
# Epoch [   10/   50] | d_loss: 1.1729 | g_loss: 2.3922
# Epoch [   10/   50] | d_loss: 1.0647 | g_loss: 0.9029
# Epoch [   10/   50] | d_loss: 1.5499 | g_loss: 0.5862
# Epoch [   10/   50] | d_loss: 0.7863 | g_loss: 1.4945
# Epoch [   10/   50] | d_loss: 0.9540 | g_loss: 1.5961
# Epoch [   10/   50] | d_loss: 0.6255 | g_loss: 1.7708
# Epoch [   10/   50] | d_loss: 0.9222 | g_loss: 1.0337
# Epoch [   10/   50] | d_loss: 0.5238 | g_loss: 1.8200
# Epoch [   11/   50] | d_loss: 0.8927 | g_loss: 1.0141
# Epoch [   11/   50] | d_loss: 0.8191 | g_loss: 0.9766
# Epoch [   11/   50] | d_loss: 0.7799 | g_loss: 1.2165
# Epoch [   11/   50] | d_loss: 1.0790 | g_loss: 1.5011
# Epoch [   11/   50] | d_loss: 0.9286 | g_loss: 0.7186
# Epoch [   11/   50] | d_loss: 1.1151 | g_loss: 1.1889
# Epoch [   11/   50] | d_loss: 0.8652 | g_loss: 2.0849
# Epoch [   11/   50] | d_loss: 0.9720 | g_loss: 1.6543
# Epoch [   12/   50] | d_loss: 0.9794 | g_loss: 1.3754
# Epoch [   12/   50] | d_loss: 0.7987 | g_loss: 1.0633
# Epoch [   12/   50] | d_loss: 1.1071 | g_loss: 1.8590
# Epoch [   12/   50] | d_loss: 1.6173 | g_loss: 2.6263
# Epoch [   12/   50] | d_loss: 1.3108 | g_loss: 1.7020
# Epoch [   12/   50] | d_loss: 1.0952 | g_loss: 1.0762
# Epoch [   12/   50] | d_loss: 0.8387 | g_loss: 1.3142
# Epoch [   12/   50] | d_loss: 0.9549 | g_loss: 1.7929
# Epoch [   13/   50] | d_loss: 0.7573 | g_loss: 1.8152
# Epoch [   13/   50] | d_loss: 0.5106 | g_loss: 2.2739
# Epoch [   13/   50] | d_loss: 0.8266 | g_loss: 1.0553
# Epoch [   13/   50] | d_loss: 0.6993 | g_loss: 1.1893
# Epoch [   13/   50] | d_loss: 1.2248 | g_loss: 2.4206
# Epoch [   13/   50] | d_loss: 1.0516 | g_loss: 1.4691
# Epoch [   13/   50] | d_loss: 0.8897 | g_loss: 1.5221
# Epoch [   13/   50] | d_loss: 0.9909 | g_loss: 1.3265
# Epoch [   14/   50] | d_loss: 0.7563 | g_loss: 1.2732
# Epoch [   14/   50] | d_loss: 0.8285 | g_loss: 1.2193
# Epoch [   14/   50] | d_loss: 0.7538 | g_loss: 1.5490
# Epoch [   14/   50] | d_loss: 0.8266 | g_loss: 1.6294
# Epoch [   14/   50] | d_loss: 0.8599 | g_loss: 1.1818
# Epoch [   14/   50] | d_loss: 0.8691 | g_loss: 1.3784
# Epoch [   14/   50] | d_loss: 0.8827 | g_loss: 1.6752
# Epoch [   14/   50] | d_loss: 1.0134 | g_loss: 1.2686
# Epoch [   15/   50] | d_loss: 0.9917 | g_loss: 0.7204
# Epoch [   15/   50] | d_loss: 0.6439 | g_loss: 1.5696
# Epoch [   15/   50] | d_loss: 0.8029 | g_loss: 1.3975
# Epoch [   15/   50] | d_loss: 1.0586 | g_loss: 2.4826
# Epoch [   15/   50] | d_loss: 0.7166 | g_loss: 0.8917
# Epoch [   15/   50] | d_loss: 1.1509 | g_loss: 1.3989
# Epoch [   15/   50] | d_loss: 0.9273 | g_loss: 1.1224
# Epoch [   15/   50] | d_loss: 1.0032 | g_loss: 1.6980
# Epoch [   16/   50] | d_loss: 1.1069 | g_loss: 1.8079
# Epoch [   16/   50] | d_loss: 1.0173 | g_loss: 2.4999
# Epoch [   16/   50] | d_loss: 0.7136 | g_loss: 1.4204
# Epoch [   16/   50] | d_loss: 0.9930 | g_loss: 2.1947
# Epoch [   16/   50] | d_loss: 0.8444 | g_loss: 1.5628
# Epoch [   16/   50] | d_loss: 0.9542 | g_loss: 1.6545
# Epoch [   16/   50] | d_loss: 0.8393 | g_loss: 1.1677
# Epoch [   16/   50] | d_loss: 0.7670 | g_loss: 1.2283
# Epoch [   17/   50] | d_loss: 1.2224 | g_loss: 2.5725
# Epoch [   17/   50] | d_loss: 0.9424 | g_loss: 1.0023
# Epoch [   17/   50] | d_loss: 0.8176 | g_loss: 1.6324
# Epoch [   17/   50] | d_loss: 0.8433 | g_loss: 1.7567
# Epoch [   17/   50] | d_loss: 0.7424 | g_loss: 1.6485
# Epoch [   17/   50] | d_loss: 0.8209 | g_loss: 1.0212
# Epoch [   17/   50] | d_loss: 0.6903 | g_loss: 1.7086
# Epoch [   17/   50] | d_loss: 0.9408 | g_loss: 2.2227
# Epoch [   18/   50] | d_loss: 1.2434 | g_loss: 2.6713
# Epoch [   18/   50] | d_loss: 1.1077 | g_loss: 2.6074
# Epoch [   18/   50] | d_loss: 0.7302 | g_loss: 1.7539
# Epoch [   18/   50] | d_loss: 0.6336 | g_loss: 1.6247
# Epoch [   18/   50] | d_loss: 0.7914 | g_loss: 1.3198
# Epoch [   18/   50] | d_loss: 1.0158 | g_loss: 0.8552
# Epoch [   18/   50] | d_loss: 0.7860 | g_loss: 1.5394
# Epoch [   18/   50] | d_loss: 0.8397 | g_loss: 1.4738
# Epoch [   19/   50] | d_loss: 1.9718 | g_loss: 3.1554
# Epoch [   19/   50] | d_loss: 1.0845 | g_loss: 0.7007
# Epoch [   19/   50] | d_loss: 0.5252 | g_loss: 3.1448
# Epoch [   19/   50] | d_loss: 0.7732 | g_loss: 2.2499
# Epoch [   19/   50] | d_loss: 0.9247 | g_loss: 2.4972
# Epoch [   19/   50] | d_loss: 0.4487 | g_loss: 2.0189
# Epoch [   19/   50] | d_loss: 1.0109 | g_loss: 3.1030
# Epoch [   19/   50] | d_loss: 0.8067 | g_loss: 1.4651
# Epoch [   20/   50] | d_loss: 0.7060 | g_loss: 2.1110
# Epoch [   20/   50] | d_loss: 0.7125 | g_loss: 1.5519
# Epoch [   20/   50] | d_loss: 0.8751 | g_loss: 1.1142
# Epoch [   20/   50] | d_loss: 0.9210 | g_loss: 1.5815
# Epoch [   20/   50] | d_loss: 0.7294 | g_loss: 2.0049
# Epoch [   20/   50] | d_loss: 1.0821 | g_loss: 1.3663
# Epoch [   20/   50] | d_loss: 0.7307 | g_loss: 1.8187
# Epoch [   20/   50] | d_loss: 0.9757 | g_loss: 1.3187
# Epoch [   21/   50] | d_loss: 0.9500 | g_loss: 2.3213
# Epoch [   21/   50] | d_loss: 0.7391 | g_loss: 1.3708
# Epoch [   21/   50] | d_loss: 0.9480 | g_loss: 1.2171
# Epoch [   21/   50] | d_loss: 0.8429 | g_loss: 1.6340
# Epoch [   21/   50] | d_loss: 0.9011 | g_loss: 2.2010
# Epoch [   21/   50] | d_loss: 1.0728 | g_loss: 1.6254
# Epoch [   21/   50] | d_loss: 1.1073 | g_loss: 1.7878
# Epoch [   21/   50] | d_loss: 0.7293 | g_loss: 1.5143
# Epoch [   22/   50] | d_loss: 0.9101 | g_loss: 2.0666
# Epoch [   22/   50] | d_loss: 0.8432 | g_loss: 1.3778
# Epoch [   22/   50] | d_loss: 0.5162 | g_loss: 2.0243
# Epoch [   22/   50] | d_loss: 1.4222 | g_loss: 2.4822
# Epoch [   22/   50] | d_loss: 0.9436 | g_loss: 0.7817
# Epoch [   22/   50] | d_loss: 0.7591 | g_loss: 1.7109
# Epoch [   22/   50] | d_loss: 0.8201 | g_loss: 1.7309
# Epoch [   22/   50] | d_loss: 0.6548 | g_loss: 2.1910
# Epoch [   23/   50] | d_loss: 1.1529 | g_loss: 2.9316
# Epoch [   23/   50] | d_loss: 0.6284 | g_loss: 1.9474
# Epoch [   23/   50] | d_loss: 0.8305 | g_loss: 1.3616
# Epoch [   23/   50] | d_loss: 0.8085 | g_loss: 1.5197
# Epoch [   23/   50] | d_loss: 0.8361 | g_loss: 1.7899
# Epoch [   23/   50] | d_loss: 0.9167 | g_loss: 1.4064
# Epoch [   23/   50] | d_loss: 0.6499 | g_loss: 1.6638
# Epoch [   23/   50] | d_loss: 0.7461 | g_loss: 1.7622
# Epoch [   24/   50] | d_loss: 0.9794 | g_loss: 0.7651
# Epoch [   24/   50] | d_loss: 0.7127 | g_loss: 1.8005
# Epoch [   24/   50] | d_loss: 0.5970 | g_loss: 1.9008
# Epoch [   24/   50] | d_loss: 0.7297 | g_loss: 1.9094
# Epoch [   24/   50] | d_loss: 0.9511 | g_loss: 2.0081
# Epoch [   24/   50] | d_loss: 1.9975 | g_loss: 0.5627
# Epoch [   24/   50] | d_loss: 0.9747 | g_loss: 1.1360
# Epoch [   24/   50] | d_loss: 0.7554 | g_loss: 1.9486
# Epoch [   25/   50] | d_loss: 0.9815 | g_loss: 1.3359
# Epoch [   25/   50] | d_loss: 0.6871 | g_loss: 1.2214
# Epoch [   25/   50] | d_loss: 0.7220 | g_loss: 1.5567
# Epoch [   25/   50] | d_loss: 0.6606 | g_loss: 2.1267
# Epoch [   25/   50] | d_loss: 0.8822 | g_loss: 0.6606
# Epoch [   25/   50] | d_loss: 1.0255 | g_loss: 1.3624
# Epoch [   25/   50] | d_loss: 0.7805 | g_loss: 1.9309
# Epoch [   25/   50] | d_loss: 0.8739 | g_loss: 2.2964
# Epoch [   26/   50] | d_loss: 1.0028 | g_loss: 1.3690
# Epoch [   26/   50] | d_loss: 0.7686 | g_loss: 2.0447
# Epoch [   26/   50] | d_loss: 0.9116 | g_loss: 1.0328
# Epoch [   26/   50] | d_loss: 0.7194 | g_loss: 1.4654
# Epoch [   26/   50] | d_loss: 0.8654 | g_loss: 1.8291
# Epoch [   26/   50] | d_loss: 0.8043 | g_loss: 2.2570
# Epoch [   26/   50] | d_loss: 0.7326 | g_loss: 1.9221
# Epoch [   26/   50] | d_loss: 0.7093 | g_loss: 1.5479
# Epoch [   27/   50] | d_loss: 0.8829 | g_loss: 1.1777
# Epoch [   27/   50] | d_loss: 0.7086 | g_loss: 1.7160
# Epoch [   27/   50] | d_loss: 1.8304 | g_loss: 0.2362
# Epoch [   27/   50] | d_loss: 0.7020 | g_loss: 1.6371
# Epoch [   27/   50] | d_loss: 1.0059 | g_loss: 0.8771
# Epoch [   27/   50] | d_loss: 0.7584 | g_loss: 1.9625
# Epoch [   27/   50] | d_loss: 0.8357 | g_loss: 1.3403
# Epoch [   27/   50] | d_loss: 0.6710 | g_loss: 2.1446
# Epoch [   28/   50] | d_loss: 0.5721 | g_loss: 1.8553
# Epoch [   28/   50] | d_loss: 0.6998 | g_loss: 1.3695
# Epoch [   28/   50] | d_loss: 0.7346 | g_loss: 2.3351
# Epoch [   28/   50] | d_loss: 0.8207 | g_loss: 2.0211
# Epoch [   28/   50] | d_loss: 0.7503 | g_loss: 2.0583
# Epoch [   28/   50] | d_loss: 0.8315 | g_loss: 1.7379
# Epoch [   28/   50] | d_loss: 0.5993 | g_loss: 1.6002
# Epoch [   28/   50] | d_loss: 0.6630 | g_loss: 2.0332
# Epoch [   29/   50] | d_loss: 1.5469 | g_loss: 3.5771
# Epoch [   29/   50] | d_loss: 0.6959 | g_loss: 1.0238
# Epoch [   29/   50] | d_loss: 0.7015 | g_loss: 0.8722
# Epoch [   29/   50] | d_loss: 0.3439 | g_loss: 1.7942
# Epoch [   29/   50] | d_loss: 0.7865 | g_loss: 2.5918
# Epoch [   29/   50] | d_loss: 0.9061 | g_loss: 1.8460
# Epoch [   29/   50] | d_loss: 0.7086 | g_loss: 1.8271
# Epoch [   29/   50] | d_loss: 0.7660 | g_loss: 2.1928
# Epoch [   30/   50] | d_loss: 0.7151 | g_loss: 4.0023
# Epoch [   30/   50] | d_loss: 0.6666 | g_loss: 1.9319
# Epoch [   30/   50] | d_loss: 0.5215 | g_loss: 2.3989
# Epoch [   30/   50] | d_loss: 0.7388 | g_loss: 1.9270
# Epoch [   30/   50] | d_loss: 0.7910 | g_loss: 1.3770
# Epoch [   30/   50] | d_loss: 0.4385 | g_loss: 2.1685
# Epoch [   30/   50] | d_loss: 0.6684 | g_loss: 1.8345
# Epoch [   30/   50] | d_loss: 0.4593 | g_loss: 1.4544
# Epoch [   31/   50] | d_loss: 0.8131 | g_loss: 3.1077
# Epoch [   31/   50] | d_loss: 0.6463 | g_loss: 1.5965
# Epoch [   31/   50] | d_loss: 0.9155 | g_loss: 1.0530
# Epoch [   31/   50] | d_loss: 0.7684 | g_loss: 1.1870
# Epoch [   31/   50] | d_loss: 0.7548 | g_loss: 1.8984
# Epoch [   31/   50] | d_loss: 0.8065 | g_loss: 1.0771
# Epoch [   31/   50] | d_loss: 0.7575 | g_loss: 2.1605
# Epoch [   31/   50] | d_loss: 0.8322 | g_loss: 2.7443
# Epoch [   32/   50] | d_loss: 0.5696 | g_loss: 1.7125
# Epoch [   32/   50] | d_loss: 0.5998 | g_loss: 1.4229
# Epoch [   32/   50] | d_loss: 0.5672 | g_loss: 2.6639
# Epoch [   32/   50] | d_loss: 0.6325 | g_loss: 1.8113
# Epoch [   32/   50] | d_loss: 0.9757 | g_loss: 0.9676
# Epoch [   32/   50] | d_loss: 0.6367 | g_loss: 1.9933
# Epoch [   32/   50] | d_loss: 0.6371 | g_loss: 1.9342
# Epoch [   32/   50] | d_loss: 0.6486 | g_loss: 2.4969
# Epoch [   33/   50] | d_loss: 0.4971 | g_loss: 1.4493
# Epoch [   33/   50] | d_loss: 0.6322 | g_loss: 1.3002
# Epoch [   33/   50] | d_loss: 0.8920 | g_loss: 1.4403
# Epoch [   33/   50] | d_loss: 0.8541 | g_loss: 1.8243
# Epoch [   33/   50] | d_loss: 0.8458 | g_loss: 2.0362
# Epoch [   33/   50] | d_loss: 0.7938 | g_loss: 1.1917
# Epoch [   33/   50] | d_loss: 0.7425 | g_loss: 1.0858
# Epoch [   33/   50] | d_loss: 0.7374 | g_loss: 1.9955
# Epoch [   34/   50] | d_loss: 0.5351 | g_loss: 1.7032
# Epoch [   34/   50] | d_loss: 0.6519 | g_loss: 2.0184
# Epoch [   34/   50] | d_loss: 0.9407 | g_loss: 1.2666
# Epoch [   34/   50] | d_loss: 0.4926 | g_loss: 1.8139
# Epoch [   34/   50] | d_loss: 0.5544 | g_loss: 1.8274
# Epoch [   34/   50] | d_loss: 0.8011 | g_loss: 2.0612
# Epoch [   34/   50] | d_loss: 0.6027 | g_loss: 1.9919
# Epoch [   34/   50] | d_loss: 0.4608 | g_loss: 2.5466
# Epoch [   35/   50] | d_loss: 0.8588 | g_loss: 2.0833
# Epoch [   35/   50] | d_loss: 0.7130 | g_loss: 1.6830
# Epoch [   35/   50] | d_loss: 0.7346 | g_loss: 1.7779
# Epoch [   35/   50] | d_loss: 0.5295 | g_loss: 2.3242
# Epoch [   35/   50] | d_loss: 0.6946 | g_loss: 2.0628
# Epoch [   35/   50] | d_loss: 0.5068 | g_loss: 2.4361
# Epoch [   35/   50] | d_loss: 0.8559 | g_loss: 2.5110
# Epoch [   35/   50] | d_loss: 1.1628 | g_loss: 1.4200
# Epoch [   36/   50] | d_loss: 0.8033 | g_loss: 1.8535
# Epoch [   36/   50] | d_loss: 0.7826 | g_loss: 1.2173
# Epoch [   36/   50] | d_loss: 0.6945 | g_loss: 3.0706
# Epoch [   36/   50] | d_loss: 0.4849 | g_loss: 2.5222
# Epoch [   36/   50] | d_loss: 0.7857 | g_loss: 2.3531
# Epoch [   36/   50] | d_loss: 0.5897 | g_loss: 1.7702
# Epoch [   36/   50] | d_loss: 0.4882 | g_loss: 1.5501
# Epoch [   36/   50] | d_loss: 0.5368 | g_loss: 2.2573
# Epoch [   37/   50] | d_loss: 0.4399 | g_loss: 1.6861
# Epoch [   37/   50] | d_loss: 0.5417 | g_loss: 1.9611
# Epoch [   37/   50] | d_loss: 0.6581 | g_loss: 2.1887
# Epoch [   37/   50] | d_loss: 0.7712 | g_loss: 1.8521
# Epoch [   37/   50] | d_loss: 0.5850 | g_loss: 1.6852
# Epoch [   37/   50] | d_loss: 0.5504 | g_loss: 2.7197
# Epoch [   37/   50] | d_loss: 0.5479 | g_loss: 1.9580
# Epoch [   37/   50] | d_loss: 0.4981 | g_loss: 1.8367
# Epoch [   38/   50] | d_loss: 0.6751 | g_loss: 2.0875
# Epoch [   38/   50] | d_loss: 0.3438 | g_loss: 1.8945
# Epoch [   38/   50] | d_loss: 0.6331 | g_loss: 1.6882
# Epoch [   38/   50] | d_loss: 0.8807 | g_loss: 3.5224
# Epoch [   38/   50] | d_loss: 0.4835 | g_loss: 2.1440
# Epoch [   38/   50] | d_loss: 0.6133 | g_loss: 1.5577
# Epoch [   38/   50] | d_loss: 0.5999 | g_loss: 1.9010
# Epoch [   38/   50] | d_loss: 0.6097 | g_loss: 1.7645
# Epoch [   39/   50] | d_loss: 1.4225 | g_loss: 3.0448
# Epoch [   39/   50] | d_loss: 0.5224 | g_loss: 2.0416
# Epoch [   39/   50] | d_loss: 0.5698 | g_loss: 2.2221
# Epoch [   39/   50] | d_loss: 0.6156 | g_loss: 1.5994
# Epoch [   39/   50] | d_loss: 0.5859 | g_loss: 1.8731
# Epoch [   39/   50] | d_loss: 0.5545 | g_loss: 2.3104
# Epoch [   39/   50] | d_loss: 0.6327 | g_loss: 2.1730
# Epoch [   39/   50] | d_loss: 0.4737 | g_loss: 2.6574
# Epoch [   40/   50] | d_loss: 0.7233 | g_loss: 2.0273
# Epoch [   40/   50] | d_loss: 0.6552 | g_loss: 1.4319
# Epoch [   40/   50] | d_loss: 0.2878 | g_loss: 2.9623
# Epoch [   40/   50] | d_loss: 0.5703 | g_loss: 1.5616
# Epoch [   40/   50] | d_loss: 0.6625 | g_loss: 2.0600
# Epoch [   40/   50] | d_loss: 0.9215 | g_loss: 1.0000
# Epoch [   40/   50] | d_loss: 0.5830 | g_loss: 2.1910
# Epoch [   40/   50] | d_loss: 0.8546 | g_loss: 2.2885
# Epoch [   41/   50] | d_loss: 0.8401 | g_loss: 2.9266
# Epoch [   41/   50] | d_loss: 0.5342 | g_loss: 2.2092
# Epoch [   41/   50] | d_loss: 0.6120 | g_loss: 2.3507
# Epoch [   41/   50] | d_loss: 0.4039 | g_loss: 2.0001
# Epoch [   41/   50] | d_loss: 0.4959 | g_loss: 2.0867
# Epoch [   41/   50] | d_loss: 0.4599 | g_loss: 2.3448
# Epoch [   41/   50] | d_loss: 0.6808 | g_loss: 1.1927
# Epoch [   41/   50] | d_loss: 0.5833 | g_loss: 2.4702
# Epoch [   42/   50] | d_loss: 0.7323 | g_loss: 1.8998
# Epoch [   42/   50] | d_loss: 0.4008 | g_loss: 2.5434
# Epoch [   42/   50] | d_loss: 0.8951 | g_loss: 2.8406
# Epoch [   42/   50] | d_loss: 0.5919 | g_loss: 2.7740
# Epoch [   42/   50] | d_loss: 0.5049 | g_loss: 2.9121
# Epoch [   42/   50] | d_loss: 0.8535 | g_loss: 0.9730
# Epoch [   42/   50] | d_loss: 0.6184 | g_loss: 1.6514
# Epoch [   42/   50] | d_loss: 0.7762 | g_loss: 1.6040
# Epoch [   43/   50] | d_loss: 0.7662 | g_loss: 1.8895
# Epoch [   43/   50] | d_loss: 0.5304 | g_loss: 3.4842
# Epoch [   43/   50] | d_loss: 0.4361 | g_loss: 2.3713
# Epoch [   43/   50] | d_loss: 0.6056 | g_loss: 2.4261
# Epoch [   43/   50] | d_loss: 0.6650 | g_loss: 2.1965
# Epoch [   43/   50] | d_loss: 0.6381 | g_loss: 1.5092
# Epoch [   43/   50] | d_loss: 0.7393 | g_loss: 1.0206
# Epoch [   43/   50] | d_loss: 0.4903 | g_loss: 1.7835
# Epoch [   44/   50] | d_loss: 0.9333 | g_loss: 3.0756
# Epoch [   44/   50] | d_loss: 0.4594 | g_loss: 1.5397
# Epoch [   44/   50] | d_loss: 0.3990 | g_loss: 2.1571
# Epoch [   44/   50] | d_loss: 0.4861 | g_loss: 1.6966
# Epoch [   44/   50] | d_loss: 0.4792 | g_loss: 1.6652
# Epoch [   44/   50] | d_loss: 0.5211 | g_loss: 1.0171
# Epoch [   44/   50] | d_loss: 0.5845 | g_loss: 2.7281
# Epoch [   44/   50] | d_loss: 0.4968 | g_loss: 2.5984
# Epoch [   45/   50] | d_loss: 2.1431 | g_loss: 0.7370
# Epoch [   45/   50] | d_loss: 0.5334 | g_loss: 1.8358
# Epoch [   45/   50] | d_loss: 0.5134 | g_loss: 1.7915
# Epoch [   45/   50] | d_loss: 0.4630 | g_loss: 2.2661
# Epoch [   45/   50] | d_loss: 0.3043 | g_loss: 1.8578
# Epoch [   45/   50] | d_loss: 0.7683 | g_loss: 1.3194
# Epoch [   45/   50] | d_loss: 0.4071 | g_loss: 2.9454
# Epoch [   45/   50] | d_loss: 0.5424 | g_loss: 1.8146
# Epoch [   46/   50] | d_loss: 1.1397 | g_loss: 4.0391
# Epoch [   46/   50] | d_loss: 0.5347 | g_loss: 2.8425
# Epoch [   46/   50] | d_loss: 0.4584 | g_loss: 2.3889
# Epoch [   46/   50] | d_loss: 0.5487 | g_loss: 2.7401
# Epoch [   46/   50] | d_loss: 0.5142 | g_loss: 1.9442
# Epoch [   46/   50] | d_loss: 0.4776 | g_loss: 1.5256
# Epoch [   46/   50] | d_loss: 0.4673 | g_loss: 2.8607
# Epoch [   46/   50] | d_loss: 0.4110 | g_loss: 1.9233
# Epoch [   47/   50] | d_loss: 0.6808 | g_loss: 2.8104
# Epoch [   47/   50] | d_loss: 0.4697 | g_loss: 2.2669
# Epoch [   47/   50] | d_loss: 0.5334 | g_loss: 2.5396
# Epoch [   47/   50] | d_loss: 0.4687 | g_loss: 1.8844
# Epoch [   47/   50] | d_loss: 0.6248 | g_loss: 2.9178
# Epoch [   47/   50] | d_loss: 0.3962 | g_loss: 2.1448
# Epoch [   47/   50] | d_loss: 0.4283 | g_loss: 2.1758
# Epoch [   47/   50] | d_loss: 0.5954 | g_loss: 2.4059
# Epoch [   48/   50] | d_loss: 0.7276 | g_loss: 3.9155
# Epoch [   48/   50] | d_loss: 0.4965 | g_loss: 4.1232
# Epoch [   48/   50] | d_loss: 0.9715 | g_loss: 1.1310
# Epoch [   48/   50] | d_loss: 0.5272 | g_loss: 2.7312
# Epoch [   48/   50] | d_loss: 0.3585 | g_loss: 1.8705
# Epoch [   48/   50] | d_loss: 0.5264 | g_loss: 1.8241
# Epoch [   48/   50] | d_loss: 0.4196 | g_loss: 1.9897
# Epoch [   48/   50] | d_loss: 0.8327 | g_loss: 2.1200
# Epoch [   49/   50] | d_loss: 0.5781 | g_loss: 2.6396
# Epoch [   49/   50] | d_loss: 0.5038 | g_loss: 2.6004
# Epoch [   49/   50] | d_loss: 0.6499 | g_loss: 1.1085
# Epoch [   49/   50] | d_loss: 0.3693 | g_loss: 2.7049
# Epoch [   49/   50] | d_loss: 0.6314 | g_loss: 2.3812
# Epoch [   49/   50] | d_loss: 0.6564 | g_loss: 2.3050
# Epoch [   49/   50] | d_loss: 0.5931 | g_loss: 1.7681
# Epoch [   49/   50] | d_loss: 0.5549 | g_loss: 2.5474
# Epoch [   50/   50] | d_loss: 2.2261 | g_loss: 3.2194
# Epoch [   50/   50] | d_loss: 0.4342 | g_loss: 2.4238
# Epoch [   50/   50] | d_loss: 0.5322 | g_loss: 1.9996
# Epoch [   50/   50] | d_loss: 0.4164 | g_loss: 3.0916
# Epoch [   50/   50] | d_loss: 0.5557 | g_loss: 2.7513
# Epoch [   50/   50] | d_loss: 0.5216 | g_loss: 2.2722
# Epoch [   50/   50] | d_loss: 0.3815 | g_loss: 2.3356
# Epoch [   50/   50] | d_loss: 1.6961 | g_loss: 3.6200
# C:\Users\halsa\miniconda3\envs\get_started_pytorch\lib\site-packages\torch\storage.py:34: FutureWarning: pickle support for Storage will be removed in 1.5. Use `torch.save` instead
#   warnings.warn("pickle support for Storage will be removed in 1.5. Use `torch.save` instead", FutureWarning)

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** I can say that I have generated photos of zombies :D
#
# The faces do not look so much real to me. I think that because I used only three convolutional layers in both the two networks. I should have constructed deeper networks.
#
# The dataset is biased. Around 80% of the generated faces in the sample above are white. I should make the dataset more balanced by equally including people from different races.
#
# I left the two networks competing against each other for 50 epochs. I can see the losses are gradually decreasing in the above graph. Therefore, If I leave it for a longer time, I think I will get better results.
#
# Finally, I may also try to generate higher resolution images by upsampling more the feature maps in the generator network.

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
